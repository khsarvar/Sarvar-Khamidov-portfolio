# %%
#pip install --use-deprecated=legacy-resolver pycaret[full]

# %%
# check version
from pycaret.utils import version
version()
# Out:
# '2.3.10'

# %%
from pycaret.datasets import get_data
#import new data here

data = get_data('insurance')
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
from pycaret.regression import *
reg1 = setup(data, target = 'charges', session_id=123, log_experiment=True, experiment_name='insurance1')
# Out:
#                                Description           Value
# 0                               session_id             123
# 1                                   Target         charges
# 2                            Original Data       (1338, 7)
# 3                           Missing Values           False
# 4                         Numeric Features               2
# 5                     Categorical Features               4
# 6                         Ordinal Features           False
# 7                High Cardinality Features           False
# 8                  High Cardinality Method            None
# 9                    Transformed Train Set       (936, 14)
# 10                    Transformed Test Set       (402, 14)
# 11                      Shuffle Train-Test            True
# 12                     Stratify Train-Test           False
# 13                          Fold Generator           KFold
# 14                             Fold Number              10
# ...

# %%
best_model = compare_models(fold=5)
# Out:
#                                     Model        MAE           MSE  \
# gbr           Gradient Boosting Regressor  2670.1805  2.301187e+07
# rf                Random Forest Regressor  2765.6686  2.519275e+07
# catboost               CatBoost Regressor  2853.7795  2.547554e+07
# lightgbm  Light Gradient Boosting Machine  3018.9895  2.551501e+07
# et                  Extra Trees Regressor  2771.2244  2.835366e+07
# ada                    AdaBoost Regressor  4366.1001  2.929822e+07
# xgboost         Extreme Gradient Boosting  3257.2767  3.148940e+07
# llar         Lasso Least Angle Regression  4326.7374  3.852320e+07
# ridge                    Ridge Regression  4347.7179  3.855164e+07
# br                         Bayesian Ridge  4344.6330  3.855109e+07
# lar                Least Angle Regression  4332.7653  3.854995e+07
# lasso                    Lasso Regression  4332.6330  3.854390e+07
# lr                      Linear Regression  4332.7660  3.854995e+07
# ...

# %%
gbr = create_model('gbr')
# Out:
#             MAE           MSE       RMSE      R2   RMSLE    MAPE
# Fold
# 0     2726.1095  2.157265e+07  4644.6365  0.8712  0.4412  0.3314
# 1     3020.0189  3.204614e+07  5660.9310  0.8137  0.4542  0.2880
# 2     2554.0978  2.132452e+07  4617.8481  0.7300  0.4760  0.3072
# 3     2830.5469  2.178529e+07  4667.4717  0.8181  0.4471  0.3480
# 4     2888.2098  2.729166e+07  5224.1422  0.7970  0.5195  0.3473
# 5     2522.7354  1.872168e+07  4326.8562  0.8796  0.3360  0.2348
# 6     2489.0907  1.985561e+07  4455.9637  0.8649  0.3574  0.2832
# 7     2709.6859  2.481789e+07  4981.7554  0.8635  0.4281  0.2666
# 8     2335.3814  1.785566e+07  4225.5957  0.8847  0.3996  0.3157
# 9     2959.2733  2.723421e+07  5218.6407  0.8246  0.5384  0.3917
# Mean  2703.5150  2.325053e+07  4802.3841  0.8347  0.4397  0.3114
# Std    212.8125  4.264177e+06   433.1725  0.0456  0.0608  0.0433
# INFO:logs:create_model_container: 22
# INFO:logs:master_model_container: 22
# INFO:logs:display_container: 4
# ...

# %%
import numpy as np
lgbms = [create_model('gbr', learning_rate=i) for i in np.arange(0.1,1,0.1)]
# Out:
#             MAE           MSE       RMSE      R2   RMSLE    MAPE
# Fold
# 0     3993.6776  4.509381e+07  6715.1923  0.7307  0.7466  0.5435
# 1     4430.8598  4.790213e+07  6921.1365  0.7215  0.6373  0.4994
# 2     3970.1247  4.104526e+07  6406.6572  0.4803  0.7853  0.6919
# 3     4115.3193  4.164592e+07  6453.3652  0.6523  0.6441  0.5522
# 4     4688.7278  5.210392e+07  7218.3042  0.6125  1.0525  0.6343
# 5     3963.9702  3.866061e+07  6217.7656  0.7513  0.6143  0.3953
# 6     3408.9527  3.032927e+07  5507.2014  0.7936  0.7121  0.4548
# 7     3748.4138  3.364966e+07  5800.8329  0.8150  0.6907  0.4590
# 8     3851.5438  4.081744e+07  6388.8529  0.7364  0.6703  0.6299
# 9     4906.6301  5.539204e+07  7442.5831  0.6432  0.7619  0.8356
# Mean  4107.8220  4.266401e+07  6507.1891  0.6937  0.7315  0.5696
# Std    426.1349  7.354962e+06   566.1229  0.0940  0.1196  0.1246
# INFO:logs:create_model_container: 31
# INFO:logs:master_model_container: 31
# INFO:logs:display_container: 13
# ...

# %%
tuned_gbr = tune_model(gbr, n_iter=50, optimize = 'MAE')
# Out:
#             MAE           MSE       RMSE      R2   RMSLE    MAPE
# Fold
# 0     2799.3266  2.240910e+07  4733.8247  0.8662  0.5039  0.3725
# 1     3017.9534  2.995664e+07  5473.2659  0.8258  0.4425  0.3067
# 2     2919.2730  2.348912e+07  4846.5580  0.7026  0.5334  0.4291
# 3     3034.8957  2.383084e+07  4881.6840  0.8010  0.5212  0.4588
# 4     3108.6680  2.892190e+07  5377.9083  0.7849  0.5364  0.3670
# 5     2684.4443  1.997542e+07  4469.3873  0.8715  0.3762  0.2844
# 6     2452.3889  1.995974e+07  4467.6320  0.8642  0.3665  0.2814
# 7     2615.5174  2.521103e+07  5021.0583  0.8614  0.4563  0.2441
# 8     2573.9514  1.866434e+07  4320.2248  0.8794  0.4559  0.3852
# 9     2862.6599  2.652777e+07  5150.5118  0.8291  0.5161  0.3793
# Mean  2806.9079  2.389459e+07  4874.2055  0.8286  0.4708  0.3508
# Std    208.5544  3.623017e+06   369.7435  0.0517  0.0591  0.0656
# INFO:logs:create_model_container: 32
# INFO:logs:master_model_container: 32
# INFO:logs:display_container: 14
# ...

# %%
tuned_gbr
# Out:
# GradientBoostingRegressor(alpha=0.9, ccp_alpha=0.0, criterion='friedman_mse',
#                           init=None, learning_rate=0.1, loss='ls', max_depth=11,
#                           max_features=1.0, max_leaf_nodes=None,
#                           min_impurity_decrease=0.5, min_impurity_split=None,
#                           min_samples_leaf=5, min_samples_split=7,
#                           min_weight_fraction_leaf=0.0, n_estimators=40,
#                           n_iter_no_change=None, presort='deprecated',
#                           random_state=123, subsample=0.45, tol=0.0001,
#                           validation_fraction=0.1, verbose=0, warm_start=False)
