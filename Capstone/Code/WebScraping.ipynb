# %%
# Import libraries
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
# Create an URL object
url = 'https://www.teamrankings.com/nba/stat/points-per-game'
# Create object page
page = requests.get(url)

# %%
# parser-lxml = Change html to Python friendly format
# Obtain page's information
soup = BeautifulSoup(page.text, 'lxml')

# %%
# Obtain information from tag <table>
table1 = soup.find('table')
#print(table1)

# %%
type(table1)
# Out:
# bs4.element.Tag

# %%
# Obtain every title of columns with tag <th>
headers = []
for i in table1.find_all('th'):
  title = i.text
  headers.append(title)

# %%
# Create a dataframe
mydata = pd.DataFrame(columns = headers)

# Create a for loop to fill mydata
for j in table1.find_all('tr')[1:]:
  row_data = j.find_all('td')
  row = [i.text for i in row_data]
  length = len(mydata)
  mydata.loc[length] = row

# %%
mydata
# Out:
#    Rank          Team   2022 Last 3 Last 1   Home   Away   2021
# 0     1        Boston  126.0  126.0  126.0  126.0     --  110.3
# 1     2  Golden State  123.0  123.0  123.0  123.0     --  111.2
# 2     3  Philadelphia  117.0  117.0  117.0     --  117.0  109.2
# 3     4     LA Lakers  109.0  109.0  109.0     --  109.0  112.1
# 4     5      New York     --     --     --     --     --  106.5
# 5     5      Brooklyn     --     --     --     --     --  112.7
# 6     5       Houston     --     --     --     --     --  109.7
# 7     5   San Antonio     --     --     --     --     --  113.0
# 8     5       Phoenix     --     --     --     --     --  113.8
# 9     5       Toronto     --     --     --     --     --  109.0
# 10    5   New Orleans     --     --     --     --     --  109.3
# 11    5     Charlotte     --     --     --     --     --  115.2
# 12    5       Memphis     --     --     --     --     --  115.2
# 13    5       Indiana     --     --     --     --     --  111.5
# ...

# %%
### In process
### To scrape different statistics

def WebSrape(link):
  page = requests.get(link)
  soup = BeautifulSoup(page.text, 'lxml')
  table1 = soup.find('table')
  headers = []
  for i in table1.find_all('th'):
    title = i.text
    headers.append(title)

  mydata = pd.DataFrame(columns = headers)

  for j in table1.find_all('tr')[1:]:
    row_data = j.find_all('td')
    row = [i.text for i in row_data]
    length = len(mydata)
    mydata.loc[length] = row
  return mydata




'''
dates = []


# Create an URL object
url = 'https://www.teamrankings.com/nba/stat/points-per-game'
# Create object page
page = requests.get(url)
#parser-lxml = Change html to Python friendly format
# Obtain page's information
soup = BeautifulSoup(page.text, 'lxml')
# Obtain information from tag <table>
table1 = soup.find('table')

headers = []
for i in table1.find_all('th'):
  title = i.text
  headers.append(title)

# Create a dataframe
mydata = pd.DataFrame(columns = headers)

# Create a for loop to fill mydata
for j in table1.find_all('tr')[1:]:
  row_data = j.find_all('td')
  row = [i.text for i in row_data]
  length = len(mydata)
  mydata.loc[length] = row
'''
# Out:
# "\ndates = []\n\n\n# Create an URL object\nurl = 'https://www.teamrankings.com/nba/stat/points-per-game'\n# Create object page\npage = requests.get(url)\n#parser-lxml = Change html to Python friendly format\n# Obtain page's information\nsoup = BeautifulSoup(page.text, 'lxml')\n# Obtain information from tag <table>\ntable1 = soup.find('table')\n\nheaders = []\nfor i in table1.find_all('th'):\n  title = i.text\n  headers.append(title)\n\n# Create a dataframe\nmydata = pd.DataFrame(columns = headers)\n\n# Create a for loop to fill mydata\nfor j in table1.find_all('tr')[1:]:\n  row_data = j.find_all('td')\n  row = [i.text for i in row_data]\n  length = len(mydata)\n  mydata.loc[length] = row\n"

# %%
# https://www.teamrankings.com/nba/player-stat/points?season_id=217&rate=per-game
# https://www.teamrankings.com/nba/player-stat/assists?season_id=217
# assists
link = 'https://www.teamrankings.com/nba/player-stat/points?season_id=217&rate=per-game'

player_pointpergame = WebSrape(link)
player_pointpergame
# Out:
#    Rank                     Player                    Team Pos  Value
# 0     1           \nJames Harden\n         Houston Rockets  SG  33.63
# 1     2           \nBradley Beal\n      Washington Wizards  SG  30.54
# 2     3         \nDamian Lillard\n  Portland Trail Blazers  PG  29.66
# 3     4             \nTrae Young\n           Atlanta Hawks  PG  29.63
# 4     5  \nGiannis Antetokounmpo\n         Milwaukee Bucks  SF  29.13
# ..  ...                        ...                     ...  ..    ...
# 95   96             \nCoby White\n           Chicago Bulls  SG  13.22
# 96   97         \nChristian Wood\n         Detroit Pistons  PF  13.06
# 97   98        \nDuncan Robinson\n              Miami Heat  SF  13.06
# 98   99            \nRicky Rubio\n            Phoenix Suns  PG  13.03
# 99  100          \nMiles Bridges\n       Charlotte Hornets  SF  12.97
#
# [100 rows x 5 columns]

# %%
player_assists_pergame = WebSrape(link)
